# %% [markdown]
# 1. You are given a data set, which is present in the LMS, containing the number of hurricanes occurring in the United States along the coast of the Atlantic. Load the data from the dataset into your program and plot a Bar Graph of the data, taking the Year as the x-axis and the number of hurricanes occurring as the Y-axis.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

h = pd.read_csv("Hurricanes.csv")
df = pd.DataFrame(h)

#df.plot(x='Year',y='Hurricanes',kind='bar')

plt.bar(df['Year'], df['Hurricanes'])
plt.xticks(np.arange(min(df['Year']),max(df['Year'])+1,10),rotation=70)
plt.xlabel('Years')
plt.ylabel('Number of hurricanes')
plt.title('Hurricanes by year')
plt.show()

# %% [markdown]
# 2. The dataset given, records data of city temperatures over the years 2014 and 2015. Plot the histogram of the temperatures over this period for the cities of San Francisco and Moscow.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

t = pd.read_csv('CityTemps.csv')
df = pd.DataFrame(t)
df

df2014 = df[df['Year']>=2014]
#df.plot(x='Year',y='Hurricanes',kind='bar')

#df[['San Francisco','Moscow']].hist()
#plt.figure(figsize=(7,4))
#plt.hist(df2014['San Francisco'],len(df2014['San Francisco']))
#plt.show()

#plt.figure(figsize=(7,4))
#plt.hist(df2014['Moscow'],len(df2014['Moscow']))
#plt.show()

#df[['San Francisco','Moscow']].hist()
plt.hist(df2014['San Francisco'],len(df2014['San Francisco']),label='San Francisco',width=.1)
plt.hist(df2014['Moscow'],len(df2014['Moscow']),label='Moscow',width=.1)
plt.xlabel('Temperature')
plt.ylabel('Frequency')
plt.legend(['San Francisco','Moscow'])
plt.title('Temperature in Sanfrancisco and Moscow during years 2014 and 2015')
plt.show()

# %% [markdown]
# 3. Plot a piechart of the number of models released by every manufacturer, recorded in the data provided. Also mention the name of the manufacturer with the largest releases.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

m = pd.read_csv('Cars2015.csv')
df = pd.DataFrame(m)
df['Make'] = df['Make'].str.strip()

df2 = df.groupby(['Make'])['Model'].count()
#df2.plot(kind='pie')
#df2.max('Model')

explode = df2.copy()
explode.values[:]=0
explode[df2.idxmax()]=.2
print("Manufacturer who has maximum number of models is: ",df2.idxmax())
print(df2.idxmax())

cmap = plt.get_cmap('Spectral')
clist = [cmap(i) for i in np.linspace(0,1,len(set(df['Make'])))]
plt.figure(figsize=(12,10))
plt.pie(df2,labels=df2.index,colors=clist,explode=explode)
#plt.title("Pie chart for Makes number of models")
plt.show()
# Out:
# Manufacturer who has maximum number of models is:  Chevrolet
# Chevrolet

# %% [markdown]
# 4. Create csv file from the data below and read it in the pandas’s dataframe.
#
# Phase 1: Reading data
#
# Phase 2: Describe the data
# Describe the data on the unit price.
#
# Phase 3: Filter the data
# Create a new dataframe having columns 'name','net_price','date' and group all the records according to name.
#
# Phase 4: Plotting graph
# Plot the graph after calculating total sales by each customer. Customer name should be the on the x-axis and total sales on y-axis. Refer to sample-salesv2 to answer the following questions

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

#Phase 1: Reading data
df = pd.read_csv("sample-salesv2.csv")

#Phase 2: Describe the data Describe the data on the unit price.
print(df['unit price'].describe())

#Phase 3: Filter the data Create a new dataframe having columns 'name','net_price','date' and group all the records according to name.

df2 = df[['name','net_price','date']].copy()

#Phase 4: Plotting graph Plot the graph after calculating total sales by each customer. Customer name should be the on the x-axis and total sales on y-axis. Refer to sample-salesv2 to answer the following questions
x = df2.groupby('name')['net_price'].sum()

plt.figure(figsize=(10,8))
plt.bar(x.index,x.values)
plt.xticks(rotation=90)
plt.xlabel('Customers')
plt.ylabel('Total sales')
plt.title('Total sales by customers')
plt.show()
# Out:
# count    1000.000000
# mean       56.179630
# std        25.331939
# min        10.060000
# 25%        35.995000
# 50%        56.765000
# 75%        76.802500
# max        99.970000
# Name: unit price, dtype: float64

# %% [markdown]
# 5. Let the x-axis data points and y-axis data points are
# X = [1,2,3,4] y = [20, 21, 20.5, 20.8]
#
# 5.1: Draw a Simple plot
# 5.2: Configure the line and markers in a simple plot
# 5.3: configure the axes
# 5.4: Give the title of the graph and labels of the x-axis and y-axis
# 5.5: Give error bar if y_error = [0.12, 0.13, 0.2, 0.1]
# 5.6: define width, and height as figsize=(4,5) DPI and adjust plot dpi=100
# 5.7: Give a font size of 14
# 5.8: Draw a scatter graph of any 50 random values of the x and y-axis
# 5.9: Create a dataframe from the following data
# 'first_name': ['Jason', 'Molly', 'Tina', 'Jake', 'Amy'],
# 'last_name': ['Miller', 'Jacobson', 'Ali', 'Milner', 'Cooze'],
# 'female': [0, 1, 1, 0, 1],
# 'age': [42, 52, 36, 24, 73],
# 'preTestScore': [4, 24, 31, 2, 3],
# 'postTestScore': [25, 94, 57, 62, 70]
# Draw a Scatterplot of preTestScore and postTestScore, with the size of each point determined by age.
# 5.10: Draw a Scatterplot from the data in question 9 of preTestScore and postTestScore with the size = 300 and the color determined by sex.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from random import randrange

X = [1,2,3,4] 
Y = [20, 21, 20.5, 20.8]

print("#5.1: Draw a Simple plot")
plt.plot(X,Y,y_error,marker='o')
plt.show()

print("#5.2: Configure the line and markers in a simple plot")
plt.plot(X,Y,marker='o')
plt.grid()
plt.show()

print("#5.3: configure the axes")
plt.plot(X,Y)
plt.xticks(rotation=90)
plt.show()

print("#5.4: Give the title of the graph and labels of the x-axis and y-axis")
plt.plot(X,Y)
plt.xlabel('X label')
plt.ylabel('Y label')
plt.title('Graph of Y and Y axes')
plt.show()

print("#5.5: Give error bar if y_error = [0.12, 0.13, 0.2, 0.1]")
y_error = [0.12, 0.13, 0.2, 0.1]
plt.plot(X,Y,y_error,marker='o')
plt.grid()
plt.xticks(rotation=90)
plt.xlabel('X label')
plt.ylabel('Y label')
plt.title('Graph of Y and Y axes')
plt.show()

print("#5.6: define width, and height as figsize=(4,5) DPI and adjust plot dpi=100")
y_error = [0.12, 0.13, 0.2, 0.1]
plt.plot(X,Y,y_error,marker='o')
plt.grid()
plt.xticks(rotation=90)
plt.xlabel('X label')
plt.ylabel('Y label')
plt.title('Graph of Y and Y axes')
plt.figure(figsize=(4,5),dpi=100)
plt.show()


print("#5.7: Give a font size of 14")
y_error = [0.12, 0.13, 0.2, 0.1]
plt.plot(X,Y,y_error,marker='o')
plt.grid()
plt.xticks(rotation=90)
plt.xlabel('X label')
plt.ylabel('Y label')
plt.title('Graph of Y and Y axes')
plt.figure(figsize=(4,5),dpi=100)
plt.rcParams.update({'font.size':11})
plt.show()

print("#5.8: Draw a scatter graph of any 50 random values of the x and y-axis")
xrand = np.random.randint(1,50,50)
yrand = np.random.randint(1,100,50)

plt.scatter(xrand,yrand)
plt.show()


print("#5.9: Create a dataframe from the following data")
#'first_name': ['Jason', 'Molly', 'Tina', 'Jake', 'Amy'],
#'last_name': ['Miller', 'Jacobson', 'Ali', 'Milner', 'Cooze'],
#'female': [0, 1, 1, 0, 1],
#'age': [42, 52, 36, 24, 73],
#'preTestScore': [4, 24, 31, 2, 3],
#'postTestScore': [25, 94, 57, 62, 70]
# Draw a Scatterplot of preTestScore and postTestScore, with the size of each point determined by age.

df = pd.DataFrame({
    'first_name': ['Jason', 'Molly', 'Tina', 'Jake', 'Amy'],
    'last_name': ['Miller', 'Jacobson', 'Ali', 'Milner', 'Cooze'],
    'female': [0, 1, 1, 0, 1],
    'age': [42, 52, 36, 24, 73],
    'preTestScore': [4, 24, 31, 2, 3],
    'postTestScore': [25, 94, 57, 62, 70]})

plt.scatter(df['preTestScore'],df['postTestScore'],s=df['age'])
plt.xlabel('preTestScore')
plt.ylabel('postTestScore')
plt.title("preTestScore vs postTestScore")
plt.show()

print("#5.10: Draw a Scatterplot from the data in question 9 of preTestScore and postTestScore with the size = 300 and ")
#the color determined by sex.

df = pd.DataFrame({
    'first_name': ['Jason', 'Molly', 'Tina', 'Jake', 'Amy'],
    'last_name': ['Miller', 'Jacobson', 'Ali', 'Milner', 'Cooze'],
    'female': [0, 1, 1, 0, 1],
    'age': [42, 52, 36, 24, 73],
    'preTestScore': [4, 24, 31, 2, 3],
    'postTestScore': [25, 94, 57, 62, 70]})

plt.scatter(df['preTestScore'],df['postTestScore'],s=300,c=df['female'],alpha=.5)
plt.xlabel('preTestScore')
plt.ylabel('postTestScore')
plt.title("preTestScore vs postTestScore")
plt.show()
# Out:
# #5.1: Draw a Simple plot
# #5.2: Configure the line and markers in a simple plot
# #5.3: configure the axes
# #5.4: Give the title of the graph and labels of the x-axis and y-axis
# #5.5: Give error bar if y_error = [0.12, 0.13, 0.2, 0.1]
# #5.6: define width, and height as figsize=(4,5) DPI and adjust plot dpi=100
# #5.7: Give a font size of 14
# #5.8: Draw a scatter graph of any 50 random values of the x and y-axis
# #5.9: Create a dataframe from the following data
# #5.10: Draw a Scatterplot from the data in question 9 of preTestScore and postTestScore with the size = 300 and

# %% [markdown]
# 6. Case Study I
# Domain – Education
# Focus – Data analysis
# Business challenge/requirement
# You are a data analyst with the University of California. The University has data of Maths, Physics and Data Structure score of sophomore students. This data is stored in different files. The University has hired a data science company to do analysis of scores and find if there is any correlation of score with age, ethnicity, etc. Before the data is given to the company, you are required to do data wrangling.
#
# Key issues
# Ensure student identity is not revealed to the agency and only relevant data is shared.
#
# Considerations
# NONE
#
# Data volume
# Only around 1800 records are shared in files MathScoreTerm1.csv, DSScoreTerm1.csv, and PhysicsScoreTerm1.csv.
#
# Additional information
# NA
#
# Business benefits
# The University can enrol more students by improving its international ranking through a personalized course/curriculum for students
#
# Approach to Solve
# You have to use the fundamentals of NumPy and pandas covered in module 5 and 6.
# 1. Read the three CSV files, which contain the score of the same students in term1 for each Subject
# 2. Remove the name and ethnicity column (to ensure confidentiality)
# 3. Fill missing score data with zero
# 4. Merge the three files
# 5. Change Sex(M/F) Column to 1/2 for further analysis
# 6. Store the data in a new file – ScoreFinal.csv
#
# You can try these enhancements in code
# 1. Convert ethnicity to a a numerical value
# 2. Fill the missing score for a student to the average of the class

# %%
#1. Read the three CSV files, which contain the score of the same students in term1 for each Subject
math_score = pd.read_csv('mathscoreterm1.csv')
phy_score = pd.read_csv('physicsscoreterm1.csv')
ds_score = pd.read_csv('dsscoreterm1.csv')


#2. Remove the name and ethnicity column (to ensure confidentiality)
#          Ethnicity  ethnicity_idx
#           Hispanic              1
#   African American              2
#     White American              3
#  European American              4
#1. Convert ethnicity to a a numerical value
ethnicity = pd.DataFrame({'Ethnicity': list(set(math_score['Ethinicity'])), 
                          'ethnicity_idx': list(set(np.arange(1,len(set(math_score['Ethinicity']))+1)))})
math_score.replace(list(ethnicity['Ethnicity']),list(ethnicity['ethnicity_idx']),inplace=True)
phy_score.replace(list(ethnicity['Ethnicity']),list(ethnicity['ethnicity_idx']),inplace=True)
ds_score.replace(list(ethnicity['Ethnicity']),list(ethnicity['ethnicity_idx']),inplace=True)

#3. Fill missing score data with zero
#2. Fill the missing score for a student to the average of the class
math_score.describe()
math_score['Score'].fillna(int(math_score['Score'].mean()),inplace=True)
math_score.describe()

phy_score.describe()
phy_score['Score'].fillna(int(phy_score['Score'].mean()),inplace=True)
phy_score.describe()

ds_score.describe()
ds_score['Score'].fillna(int(ds_score['Score'].mean()),inplace=True)
ds_score.describe()


#4. Merge the three files

full_score=pd.concat([math_score,phy_score])
full_score = pd.concat([full_score, ds_score])
full_score


#5. Change Sex(M/F) Column to 1/2 for further analysis
MF = pd.Series({'idx':[1,2],'vals':['M','F']})
full_score['Sex'].replace(MF['vals'],MF['idx'],inplace=True)
full_score.describe()

#6. Store the data in a new file – ScoreFinal.csv
full_score.to_csv('ScoreFinal.csv')

# %%
a = [1,2,3,4,5]

list(map(lambda x: x**2,a))
# Out:
# [1, 4, 9, 16, 25]

# %%
a = [1,2,3,4,5]

list(map(lambda x: x%2==0,a))
# Out:
# [False, True, False, True, False]

# %%
from pandas import DataFrame as pd

# %%
import pandas.arrays as pa

# %%
import pandas.DataFrame as df
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [8], in <cell line: 1>()
# ----> 1 import pandas.DataFrame as df
#
# ModuleNotFoundError: No module named 'pandas.DataFrame'
